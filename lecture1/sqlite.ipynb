# %%
import sqlite3

# %%
path = ''

db_name = 'test.db'

#DBに接続
conn = sqlite3.connect(path + db_name)

#接続を閉じる
conn.close()

# %%
path = ''
db_name = 'car.db'

conn = sqlite3.connect(path + db_name)

cur = conn.cursor()

sql = 'create table cars (id int,name text,price real);'

# cur.execute(sql)

conn.close()

# %% [markdown]
# # データ挿入
